# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Group-members" data-toc-modified-id="Group-members-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Group members</a></span><ul class="toc-item"><li><span><a href="#Group-12:-Lu-Wang,-Xiqing-Mao,-Zelin-Li" data-toc-modified-id="Group-12:-Lu-Wang,-Xiqing-Mao,-Zelin-Li-0.1.1"><span class="toc-item-num">0.1.1&nbsp;&nbsp;</span>Group 12: Lu Wang, Xiqing Mao, Zelin Li</a></span></li></ul></li></ul></li><li><span><a href="#Foreword" data-toc-modified-id="Foreword-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Foreword</a></span><ul class="toc-item"><li><span><a href="#Work-environment:" data-toc-modified-id="Work-environment:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Work environment:</a></span></li><li><span><a href="#Sources:" data-toc-modified-id="Sources:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Sources:</a></span></li><li><span><a href="#Main-task:" data-toc-modified-id="Main-task:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Main task:</a></span></li><li><span><a href="#Library-overview" data-toc-modified-id="Library-overview-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Library overview</a></span></li></ul></li><li><span><a href="#Task_2" data-toc-modified-id="Task_2-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Task_2</a></span><ul class="toc-item"><li><span><a href="#Read-file" data-toc-modified-id="Read-file-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Read file</a></span><ul class="toc-item"><li><span><a href="#Group-the-column-&quot;type&quot;-with-descending-order" data-toc-modified-id="Group-the-column-&quot;type&quot;-with-descending-order-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Group the column "type" with descending order</a></span></li><li><span><a href="#Remove-duplicate-contents" data-toc-modified-id="Remove-duplicate-contents-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Remove duplicate contents</a></span></li><li><span><a href="#Select-useful-information" data-toc-modified-id="Select-useful-information-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Select useful information</a></span></li><li><span><a href="#Check-and-drop-empty-(N/A)-value" data-toc-modified-id="Check-and-drop-empty-(N/A)-value-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Check and drop empty (N/A) value</a></span></li></ul></li><li><span><a href="#Types-of-articles" data-toc-modified-id="Types-of-articles-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Types of articles</a></span><ul class="toc-item"><li><span><a href="#Description-of-the-article-type-distribution" data-toc-modified-id="Description-of-the-article-type-distribution-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Description of the article-type distribution</a></span></li><li><span><a href="#Eliminate-insufficient-samples-by-merge-labels" data-toc-modified-id="Eliminate-insufficient-samples-by-merge-labels-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Eliminate insufficient samples by merge labels</a></span></li></ul></li><li><span><a href="#Domain-of-the-articles" data-toc-modified-id="Domain-of-the-articles-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Domain of the articles</a></span><ul class="toc-item"><li><span><a href="#Description-of-the-article-domain-distribution" data-toc-modified-id="Description-of-the-article-domain-distribution-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Description of the article-domain distribution</a></span></li></ul></li><li><span><a href="#Clean-data" data-toc-modified-id="Clean-data-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Clean data</a></span><ul class="toc-item"><li><span><a href="#Use-Regular-Expression-to-clean-data" data-toc-modified-id="Use-Regular-Expression-to-clean-data-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Use Regular Expression to clean data</a></span></li><li><span><a href="#Tokenize" data-toc-modified-id="Tokenize-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Tokenize</a></span></li></ul></li></ul></li><li><span><a href="#Task_3" data-toc-modified-id="Task_3-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Task_3</a></span><ul class="toc-item"><li><span><a href="#Observations-about-the-FakeNewsCorpus-dataset." data-toc-modified-id="Observations-about-the-FakeNewsCorpus-dataset.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Observations about the FakeNewsCorpus dataset.</a></span><ul class="toc-item"><li><span><a href="#Base-on-the-column-&quot;content&quot;,-count-the-url,-date-and-numerical-value." data-toc-modified-id="Base-on-the-column-&quot;content&quot;,-count-the-url,-date-and-numerical-value.-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Base on the column "content", count the url, date and numerical value.</a></span></li><li><span><a href="#Count-words-for-&quot;content&quot;-and-&quot;title&quot;" data-toc-modified-id="Count-words-for-&quot;content&quot;-and-&quot;title&quot;-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Count words for "content" and "title"</a></span><ul class="toc-item"><li><span><a href="#Content" data-toc-modified-id="Content-3.1.2.1"><span class="toc-item-num">3.1.2.1&nbsp;&nbsp;</span>Content</a></span></li><li><span><a href="#Title" data-toc-modified-id="Title-3.1.2.2"><span class="toc-item-num">3.1.2.2&nbsp;&nbsp;</span>Title</a></span></li></ul></li></ul></li><li><span><a href="#Patterns" data-toc-modified-id="Patterns-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Patterns</a></span><ul class="toc-item"><li><span><a href="#Remove-stopwords-and-stemmings" data-toc-modified-id="Remove-stopwords-and-stemmings-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Remove stopwords and stemmings</a></span></li><li><span><a href="#Word-frequency" data-toc-modified-id="Word-frequency-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Word frequency</a></span></li></ul></li><li><span><a href="#Visualize-the-observation-of-dataset-by-Wordcloud" data-toc-modified-id="Visualize-the-observation-of-dataset-by-Wordcloud-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Visualize the observation of dataset by Wordcloud</a></span><ul class="toc-item"><li><span><a href="#Without-removing-stopwords-by-&quot;type&quot;" data-toc-modified-id="Without-removing-stopwords-by-&quot;type&quot;-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Without removing stopwords by "type"</a></span><ul class="toc-item"><li><span><a href="#Type:-fake" data-toc-modified-id="Type:-fake-3.3.1.1"><span class="toc-item-num">3.3.1.1&nbsp;&nbsp;</span>Type: fake</a></span></li><li><span><a href="#Type:-others" data-toc-modified-id="Type:-others-3.3.1.2"><span class="toc-item-num">3.3.1.2&nbsp;&nbsp;</span>Type: others</a></span></li><li><span><a href="#Type:-reliable" data-toc-modified-id="Type:-reliable-3.3.1.3"><span class="toc-item-num">3.3.1.3&nbsp;&nbsp;</span>Type: reliable</a></span></li><li><span><a href="#Discussion" data-toc-modified-id="Discussion-3.3.1.4"><span class="toc-item-num">3.3.1.4&nbsp;&nbsp;</span>Discussion</a></span></li></ul></li><li><span><a href="#With-removing-stopwords-by-&quot;type&quot;" data-toc-modified-id="With-removing-stopwords-by-&quot;type&quot;-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>With removing stopwords by "type"</a></span><ul class="toc-item"><li><span><a href="#Type:-fake" data-toc-modified-id="Type:-fake-3.3.2.1"><span class="toc-item-num">3.3.2.1&nbsp;&nbsp;</span>Type: fake</a></span></li><li><span><a href="#Type:-others" data-toc-modified-id="Type:-others-3.3.2.2"><span class="toc-item-num">3.3.2.2&nbsp;&nbsp;</span>Type: others</a></span></li><li><span><a href="#Type:-reliable" data-toc-modified-id="Type:-reliable-3.3.2.3"><span class="toc-item-num">3.3.2.3&nbsp;&nbsp;</span>Type: reliable</a></span></li><li><span><a href="#Discussion" data-toc-modified-id="Discussion-3.3.2.4"><span class="toc-item-num">3.3.2.4&nbsp;&nbsp;</span>Discussion</a></span></li></ul></li></ul></li><li><span><a href="#Extract-the-numerical-values-(digits)-in-contents" data-toc-modified-id="Extract-the-numerical-values-(digits)-in-contents-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Extract the numerical values (digits) in contents</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#Task_4" data-toc-modified-id="Task_4-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Task_4</a></span><ul class="toc-item"><li><span><a href="#Range-of--letters" data-toc-modified-id="Range-of--letters-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Range of  letters</a></span></li><li><span><a href="#Scraping-and-create-data-set" data-toc-modified-id="Scraping-and-create-data-set-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Scraping and create data set</a></span><ul class="toc-item"><li><span><a href="#Method-1:-Scrapy-by-simulate-click" data-toc-modified-id="Method-1:-Scrapy-by-simulate-click-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Method 1: Scrapy by simulate click</a></span><ul class="toc-item"><li><span><a href="#Webdriver-ATTENTION!" data-toc-modified-id="Webdriver-ATTENTION!-4.2.1.1"><span class="toc-item-num">4.2.1.1&nbsp;&nbsp;</span>Webdriver ATTENTION!</a></span></li></ul></li><li><span><a href="#Method-2:-with-Regular-Expression" data-toc-modified-id="Method-2:-with-Regular-Expression-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Method 2: with Regular Expression</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#Task_5-&amp;-6" data-toc-modified-id="Task_5-&amp;-6-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Task_5 &amp; 6</a></span></li></ul></div>

# %% [markdown]
# <font color="#000066" size="6">
# Data Science 2021_Milestone 1
# </font>

# %% [markdown]
# ## Group members
# ### Group 12: Lu Wang, Xiqing Mao, Zelin Li

# %% [markdown]
# <table><tr><td bgcolor=#f2ffe5>
#
# # Foreword
#
# </td></tr></table></font>

# %% [markdown]
# ## Work environment:
#
# Python 3 in Jupyter notebook

# %% [markdown]
# ## Sources:
# https://github.com/several27/FakeNewsCorpus
#
# https://raw.githubusercontent.com/several27/FakeNewsCorpus/master/news_sample.csv
#
# https://en.wikinews.org/wiki/Category:Politics_and_conflicts

# %% [markdown]
# ## Main task:
#
# Retrieving, structuring, clean and observing data.

# %% [markdown]
# ## Library overview
#
# You will find the following libraries in this milestone. Here is the overview that states why these are appropriate to use.
#
# + pandas: Convenient to import and analyze data, dataframe is extraordinary.
#
# + numpy: Convenient to work with arrays, linear algebra, etc.
#
# + seaborn: Data visualization library based on matplotlib.
#
# + matplotlib: Along with seaborn, it provides informative statistical graphics.
#
# + re: A special sequence of characters that helps you match or find other strings.
#
# + nltk: Used in text analysis operations.
#
# + wordcloud: Represent the frequency/importance of each word.
#
# + requests:  Allow to send HTTP requests and use API.
#
# + tqdm: Progress-bar library for nested loops.
#
# + BeautifulSoup: Pulling data out of HTML and XML files.
#
# + codecs: Encoding conversion(str & unicode).
#
# + csv: Import and export format for spreadsheets and databases.
#
# + selenium: Selenium WebDriver can be used with Python for testing.

# %% [markdown]
# <table><tr><td bgcolor=#f2ffe5>
#
# # Task_2
#
# </td></tr></table>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read file

# %%
news = pd.read_csv("https://raw.githubusercontent.com/several27/FakeNewsCorpus/master/news_sample.csv", index_col = 0)
news.head(3)
# Out:
#     id             domain        type  \
# 0  141            awm.com  unreliable
# 1  256  beforeitsnews.com        fake
# 2  700        cnnnext.com  unreliable
#
#                                                  url  \
# 0  http://awm.com/church-congregation-brings-gift...
# 1  http://beforeitsnews.com/awakening-start-here/...
# 2  http://www.cnnnext.com/video/18526/never-hike-...
#
#                                              content  \
# 0  Sometimes the power of Christmas will make you...
# 1  AWAKENING OF 12 STRANDS of DNA – “Reconnecting...
# 2  Never Hike Alone: A Friday the 13th Fan Film U...
#
#                    scraped_at                 inserted_at  \
# 0  2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 1  2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 2  2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
#
#                    updated_at  \
# 0  2018-02-02 01:19:41.756664
# 1  2018-02-02 01:19:41.756664
# 2  2018-02-02 01:19:41.756664
#
# ...

# %% [markdown]
# ### Group the column "type" with descending order

# %%
news.groupby('type').size().sort_values(ascending = False)
# Out:
# type
# fake          155
# conspiracy     31
# political      23
# unreliable      6
# unknown         6
# junksci         6
# bias            6
# reliable        3
# hate            1
# clickbait       1
# dtype: int64

# %% [markdown]
# ###  Remove duplicate contents

# %%
news2 = news.drop_duplicates('content', 'first')
news2.groupby('type').size().sort_values(ascending = False)
# Out:
# type
# fake          146
# conspiracy     31
# political      22
# unreliable      6
# unknown         6
# bias            6
# junksci         5
# reliable        3
# hate            1
# clickbait       1
# dtype: int64

# %% [markdown]
# ### Select useful information
# **Hereby: 'id', 'type', 'content', 'title' and 'domain'**

# %%
df = pd.DataFrame(news2, columns = ['id', 'type', 'content', 'title', 'domain'])
df.head(3)
# Out:
#     id        type                                            content  \
# 0  141  unreliable  Sometimes the power of Christmas will make you...
# 1  256        fake  AWAKENING OF 12 STRANDS of DNA – “Reconnecting...
# 2  700  unreliable  Never Hike Alone: A Friday the 13th Fan Film U...
#
#                                                title             domain
# 0  Church Congregation Brings Gift to Waitresses ...            awm.com
# 1  AWAKENING OF 12 STRANDS of DNA – “Reconnecting...  beforeitsnews.com
# 2  Never Hike Alone - A Friday the 13th Fan Film ...        cnnnext.com

# %% [markdown]
# ### Check and drop empty (N/A) value

# %%
df.isnull().sum()
# Out:
# id          0
# type       12
# content     0
# title       0
# domain      0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ## Types of articles
# ### Description of the article-type distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("whitegrid")
sns.set_palette('pastel')
type_plot = sns.catplot('type', data = df, kind = 'count')
(type_plot.set_xticklabels(rotation=30).ax.set_title('Number of articles by type', fontsize = 14))
# Out:
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of articles by type')

# %% [markdown]
# ### Eliminate insufficient samples by merge labels

# %%
df['type'].replace(['conspiracy', 'junksci', 'rumor', 'hate', 'unreliable', 'clickbait', 'unknown', 'satire', 'bias', 'political'], 'others', inplace = True)

# %%
type_plot2 = sns.catplot('type', data = df, kind = 'count', )
(type_plot2.set_xticklabels(rotation=30)
          .ax.set_title('Number of articles by merged type', fontsize = 14)
          )
# Out:
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of articles by merged type')

# %% [markdown]
# ## Domain of the articles
# ### Description of the article-domain distribution
# <table><tr><td bgcolor=#ffffe5>
# Comment: Notice that a domain can only supply one type of news.
# </td></tr></table>

# %%
domain_plot = sns.catplot(x="domain", hue="type", data=df, kind="count", legend_out=False)
(domain_plot.set_xticklabels(rotation = 90)
            .set(yscale = 'log', title = 'Number of articles by domain')
            .fig.set_size_inches(15,4))

# %% [markdown]
# ## Clean data

# %%
import re
import nltk

# %% [markdown]
# ### Use Regular Expression to clean data

# %%
# define regexp for date

monthsShort = "Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec"
monthsLong = "January|February|March|April|May|June|July|August|September|October|November|December"
months = "(" + monthsShort + "|" + monthsLong + ")"
separators = "[-/\s,.]"
days = "\d{2}"
years = "\d{4}"
regex1 = "(" + months + separators + days + "|" + years + ")"
regex2 = "(" + days + separators + months + "|" + years + ")"
regex3 = '^([1-9]|0[1-9]|1[0-9]|2[0-9]|3[0-1])(\.|-|\/)([1-9]|0[1-9]|1[0-2])(\.|-|\/)([0-9][0-9]|19[0-9][0-9]|20[0-9][0-9])$|^([0-9][0-9]|19[0-9][0-9]|20[0-9][0-9])(\.|-|\/)([1-9]|0[1-9]|1[0-2])(\.|-|\/)([1-9]|0[1-9]|1[0-9]|2[0-9]|3[0-1])$'


# define regexp for the text 

def my_clean_text(text):
    #replace multiple \s to single space and lower the text
    text = re.sub(r'(\\n)+|(\\t)+|\s{2,}', ' ', text).lower()
    #Replace email to <EMAIL>
    text = re.sub(r'^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$', ' <EMAIL> ', text)
    #Replace URLs to <URL>
    text = re.sub(r'((http|ftp|https):\/\/)?[\w\-_]+(\.[\w\-_]+)+([\w\-\.,@?^=%&amp;:/~\+#]*[\w\-\@?^=%&amp;/~\+#])?', ' <URL> ', text)
    #Replace date to <DATE>
    text = re.sub(regex1, ' <DATE> ', text); text = re.sub(regex2, ' <DATE> ', text); text = re.sub(regex3, ' <DATE> ', text)
    #remove sign at start or end of the words
    text = re.sub(r'[^\w\s>]+\s|\s+[^\w\s<]', ' ', text)
    #remove in-words sign expect -,<,> and '
    text = re.sub(r'[^\w\s\-<>\']', '', text)
    #replace any numbers to <NUM>
    text = re.sub(r'[\d+,?]\.?\d*', ' <NUM> ', text)
    #replace multiple \s to single space again
    text = re.sub(r'\s{2,}', ' ', text)
    #text = re.sub(r'["”“@()*|\'#!≥+.,$€%&"]', ' ', text) #remove spical char
    return text

# %%
df2 = df.copy(deep=True)
df2['content'] = df2.apply(lambda x: my_clean_text(x['content']), axis=1)
df2['title'] = df2.apply(lambda x: my_clean_text(x['title']), axis=1)

# %% [markdown]
# ### Tokenize

# %%
from nltk.tokenize import RegexpTokenizer

# %%
def tok(text):
    tokenizer = RegexpTokenizer('\S+')
    tokens = tokenizer.tokenize(text)
    voc = [i for i in tokens]# if i.isalpha()]
    return voc

# %%
df4 = df2.copy(deep=True)
# tokenize contents
df4['content'] = df4.apply(lambda x: tok(x['content']), axis=1)
# tokenize title
df4['title'] = df4.apply(lambda x: tok(x['title']), axis=1)

# %% [markdown]
# <table><tr><td bgcolor=#f2ffe5>
#
# # Task_3
#
# </td></tr></table>

# %% [markdown]
# ## Observations about the FakeNewsCorpus dataset.
# ### Base on the column "content", count the url, date and numerical value.

# %%
df4_1 = df4.explode('content').reset_index(drop=True)
count = pd.crosstab(df4_1.type,df4_1.content)

print('Count the number of URLs in fake, other, reliable: ', count.loc['fake']['<URL>'],',', count.loc['others']['<URL>'],',', count.loc['reliable']['<URL>'])
print('Count the number of dates in fake, other, reliable: ', count.loc['fake']['<DATE>'], ',',count.loc['others']['<DATE>'], ',',count.loc['reliable']['<DATE>'])
print('Count the number of numeric values fake, other, reliable: ', count.loc['fake']['<NUM>'],',', count.loc['others']['<NUM>'], ',',count.loc['reliable']['<NUM>'])
# Out:
# Count the number of URLs in fake, other, reliable:  624 , 211 , 3
# Count the number of dates in fake, other, reliable:  472 , 226 , 4
# Count the number of numeric values fake, other, reliable:  998 , 504 , 14

# %% [markdown]
# ### Count words for "content" and "title"

# %%
df4_2 = df4.copy(deep=True)
df4_2['content'] = df4_2.apply(lambda x: [i for i in x['content'] if i.isalpha()], axis=1)
df4_2['title'] = df4_2.apply(lambda x: [i for i in x['title'] if i.isalpha()], axis=1)

df4_2['len_content'] = df4_2.apply(lambda x: len(x['content']), axis=1)
df4_2['len_title'] = df4_2.apply(lambda x: len(x['title']), axis=1)

# %% [markdown]
# #### Content

# %%
box1 = sns.boxplot(x=df4_2['type'], y=df4_2['len_content'])
box1.set(ylabel='word count')
box1.set_title('Word count of different types for contents', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Word count of different types for contents')

# %%
dis1 = sns.kdeplot(data = df4_2, x="len_content", hue = 'type', bw_adjust=.25, fill=True)
dis1.set(xlabel='word count')
dis1.set_title('Word count of different types for contents', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Word count of different types for contents')

# %% [markdown]
# #### Title

# %%
box2 = sns.boxplot(x=df4_2['type'], y=df4_2['len_title'])
box2.set(ylabel='word count')
box2.set_title('Word count of different types for titles', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Word count of different types for titles')

# %%
dis2 = sns.kdeplot(data = df4_2, x="len_title", hue = 'type', bw_adjust=.25, fill=True)
dis2.set(xlabel='word count')
dis2.set_title('Word count of different types for titles', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Word count of different types for titles')

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
#
# Comment: It seems that 'fake' news longer than 'reliable' in both contents and titles.
# </td></tr></table>

# %% [markdown]
# ##  Patterns

# %% [markdown]
# ###  Remove stopwords and stemmings

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')

# %%
df5 = df4_2.copy(deep=True)
from nltk.corpus import stopwords 
df5['content'] = df5.apply(lambda x: ([w for w in x['content'] if not w in stopwords.words('english')]), axis=1)
df5['len_content'] = df5.apply(lambda x: len(x['content']), axis=1)

# %%
# reduction rate
def rr(data):
    expened_df = len(set(data.explode('content').reset_index(drop=True)['content']))
    len_tok = len(set(df4_2.explode('content').reset_index(drop=True)['content']))
    rr = (len_tok - expened_df) / len_tok
    return rr
print('Reduction rate of contents after removing stopwords :', rr(df5))
# Out:
# Reduction rate of contents after removing stopwords : 0.00869164416935537

# %%
from nltk.stem.porter import *
df6 = df5.copy(deep = True)
df6['content'] = df6.apply(lambda x: ([PorterStemmer().stem(i) for i in x['content']]), axis=1)
df6['len_content'] = df6.apply(lambda x: len(x['content']), axis=1)
print('Reduction rate of contents after stemming :', rr(df6))
# Out:
# Reduction rate of contents after stemming : 0.35444788305787844

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
# Comment: Reduction rate for remove stopwords of content is approximate 0.9%.  Reduction rate for remove stemmings of content is approximate 35.4%.
# </td></tr></table>

# %% [markdown]
# ###  Word frequency

# %%
# without removing stopwords and stemming
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
df4_3 = df4_2.copy(deep = True)
df4_3 = df4_3.drop(columns = ['id', 'title', 'domain', 'len_content',"len_title"])
df4_3 = df4_3.explode('content').reset_index(drop=True)
df4_3[['content', 'type']].groupby(['content']).size().nlargest(100).reset_index(name = 'top100')
# Out:
#        content  top100
# 0          the    9130
# 1           of    4783
# 2           to    4735
# 3          and    4533
# 4            a    3268
# 5           in    2992
# 6           is    2257
# 7         that    2136
# 8          for    1506
# 9           it    1309
# 10         are    1207
# 11        with    1136
# 12         you    1135
# 13        this    1133
# 14          on    1114
# 15          as    1058
# 16          be     899
# 17           i     853
# 18          by     800
# 19         was     767
# 20        have     766
# 21         not     712
# 22          at     690
# 23        from     682
# 24          or     668
# 25          we     597
# 26        they     586
# 27         but     575
# 28         its     560
# 29        your     551
# 30         has     508
# 31          an     502
# 32       their     502
# 33         all     480
# 34        will     462
# 35        more     458
# 36       about     449
# 37         can     441
# 38          if     437
# ...

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
# Comment: The most appeared words are "the", "of" and "to" (English content only). We need remove these stopwords and stemmings.
# </td></tr></table>

# %%
# with removing stopwords and stemming
df6_1 = df6.copy(deep = True)
df6_1 = df6_1.drop(columns = ['id', 'title', 'domain', 'len_content',"len_title"])
df6_1 = df6_1.explode('content').reset_index(drop=True)
df6_1[['content', 'type']].groupby(['content']).size().nlargest(100).reset_index(name = 'top100')
# Out:
#        content  top100
# 0          one     449
# 1         like     397
# 2         time     378
# 3        peopl     374
# 4        state     348
# 5        trump     321
# 6          use     312
# 7        would     311
# 8       market     291
# 9           us     274
# 10        year     273
# 11        also     269
# 12  blockchain     260
# 13         new     259
# 14        make     247
# 15       thing     233
# 16          go     228
# 17       think     225
# 18         way     225
# 19        mani     218
# 20      govern     216
# 21      report     216
# 22        said     214
# 23        even     211
# 24        next     211
# 25         get     207
# 26      nation     207
# 27        take     204
# 28         see     199
# 29       could     198
# 30       stock     187
# 31         may     183
# 32      presid     183
# 33         say     182
# 34         two     181
# 35        work     180
# 36       world     179
# 37    american     177
# 38       first     177
# ...

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
# Comment: The most appeared words are "one", "like" and "time" after removing stopwords and stemming.
# </td></tr></table>

# %% [markdown]
# ## Visualize the observation of dataset by Wordcloud

# %% [markdown]
# ### Without removing stopwords by "type"

# %%
from wordcloud import WordCloud

# %%
df10 = df4_2.explode('content').reset_index(drop=True)
df11 = df10.drop(columns=['id', 'title', 'domain', 'len_content','len_title'])
def my_merge(df):
    return','.join(df.values)
df11 = df11.groupby(['type'])['content'].apply(my_merge)
df11 = df11.reset_index()

# %% [markdown]
# #### Type: fake

# %%
# fake
wordcloud = WordCloud(background_color="white",width=2000, height=1720, margin=2).generate(df11['content'][0])
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Type: others

# %%
# others
wordcloud = WordCloud(background_color="white",width=2000, height=1720, margin=2).generate(df11['content'][1])
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Type: reliable

# %%
# reliable
wordcloud = WordCloud(background_color="white",width=2000, height=1720, margin=2).generate(df11['content'][2])
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Discussion
# Without removing those stopwords and stemmings, We can see, "will" is the most noticable word in both "fake" and "others".
#
# In type "reliable", word "luis" stands out among all the other words.
#
# Furthermore, there are two "cell"s in the same picture.
# We guess one "cell" belongs to the 'stem cell' because they have the same size, two 'cell's should be merged after tokenizing. However it shows up in the picture, we need to do further research.

# %% [markdown]
# ### With removing stopwords by "type"

# %%
df12 = df6.explode('content').reset_index(drop=True)
df13 = df12.drop(columns=['id', 'title', 'domain', 'len_title', 'len_content'])
def my_merge(df):
    return','.join(df.values)
df13 = df13.groupby(['type'])['content'].apply(my_merge)
df13 = df13.reset_index()

# %% [markdown]
# #### Type: fake

# %%
# fake
wordcloud = WordCloud(background_color="white",width=2000, height=1720, margin=2).generate(df13['content'][0])
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Type: others

# %%
# others
wordcloud = WordCloud(background_color="white",width=2000, height=1720, margin=2).generate(df13['content'][1])
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Type: reliable

# %%
# reliable
wordcloud = WordCloud(background_color="white",width=2000, height=1720, margin=2).generate(df13['content'][2])
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Discussion
# The word "will" disappeared after removing stopwords and stemmings.
# High-frequency words in "fake" and "others" are quite similar, such as "one", "time", etc.
#
# In "reliable", "luis" becomes "lui".
# People's names take a significant proportion.

# %% [markdown]
# ## Extract the numerical values (digits) in contents

# %%
df7 = df.copy(deep=True)
df7['dig_in_content'] = df7.apply(lambda x: re.sub(r'((http|ftp|https):\/\/)?[\w\-_]+(\.[\w\-_]+)+([\w\-\.,@?^=%&amp;:/~\+#]*[\w\-\@?^=%&amp;/~\+#])?', '', x['content']), axis=1)
df7['dig_in_content'] = df7.apply(lambda x: re.findall(r'\d+\.?\d*',x['dig_in_content']), axis=1)
df8 = df7.copy(deep=True)
df8 = df8.explode('dig_in_content').reset_index(drop=True)
df8 = df8.dropna()
df8['dig_in_content'] = df8['dig_in_content'].astype(float)
df8.groupby('type')['dig_in_content'].describe()
# Out:
#            count         mean           std  min   25%   50%     75%       max
# type
# fake      1596.0  1583.602130  15462.682027  0.0   8.0  40.0  1978.0  411001.0
# others     787.0   623.950445    890.367591  0.0  12.0  40.0  1950.5    5000.0
# reliable    21.0   397.047619    799.932089  0.0   4.0  10.0    60.0    2018.0

# %%
box3 = sns.boxplot(x=df8['type'], y=df8['dig_in_content'])
box3.set(ylabel='digit')
box3.set_title('Digits of different types for "content"', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Digits of different types for "content"')

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
# **Comment: In "fake" category, there are outliers above 400000.**
# </td></tr></table>

# %%
from matplotlib.cbook import boxplot_stats

# %%
np.sort(boxplot_stats(df8['dig_in_content']).pop(0)['fliers'])
# Out:
# array([  5000.,   5000.,   5000.,   5195.,   5441.,   5441.,   7241.,
#          7241.,   7419.,   8507.,   9126.,   9126.,   9674.,   9750.,
#         10951.,  11051.,  11051.,  12881.,  13526.,  13642.,  17304.,
#         49827.,  61401.,  69200.,  71362.,  75252.,  95640., 120000.,
#        409020., 411001.])

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
#
#
# Comment: After printing outliers out, we can see some large values are "409020" and "411001". Our research turns out that they are postcode. These values may unrelated with contents, thus we want to see the pattern after removing such numbers.
# </td></tr></table>

# %%
df9 = df8.drop(df8[df8['dig_in_content'] > 12000].index)
df9.groupby('type')['dig_in_content'].describe()
# Out:
#            count        mean          std  min   25%   50%     75%      max
# type
# fake      1583.0  699.540745  1175.531402  0.0   8.0  38.0  1969.5  11051.0
# others     787.0  623.950445   890.367591  0.0  12.0  40.0  1950.5   5000.0
# reliable    21.0  397.047619   799.932089  0.0   4.0  10.0    60.0   2018.0

# %%
box4 = sns.boxplot(x=df9['type'], y=df9['dig_in_content'])
box4.set(ylabel='digit')
box4.set_title('Digits of different types for "contents" (outliers removed)', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Digits of different types for "contents" (outliers removed)')

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
#
#
# Comment: After removing postcodes, we found that type "fake" still contains larger numerical values than "others" and "reliable". Digits of "reliable" is around 2000, "others" is around 5000, and "fake" is 5000 and above.
#
# </td></tr></table>

# %%
dis3 = sns.kdeplot(data = df9, x="dig_in_content", hue = 'type', bw_adjust=.25, fill=True)
dis3.set(xlabel='digit')
dis3.set_title('digits of different types for contents', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'digits of different types for contents')

# %%
dis4 = sns.kdeplot(data = df9, hue = 'type', x="dig_in_content", bw_adjust=.25, fill=True, clip=(0,3500))
dis4.set(xlabel='digit')
dis4.set_title('digits of different types for contents, cut off at 3500', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'digits of different types for contents, cut off at 3500')

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
#
# Comment: There are 2 peaks, one is around 1. Another is around 2000, which represents the number of the years.
# </td></tr></table>

# %% [markdown]
# ## Conclusion
#
# We should notice that, in this dataset, type "fake" occupy a overwhelming procentage, while "reliable" only has 3 source. This leads 'fake' news has higher results in many steps, for example, the number of dates in "fake" is 472, while only 4 in "reliable", and the probability density of 'fake' also larger than 'reliable'. Therefore the data are not impartial.
#
# Base on our observation, "Fake" news also contains a large amount of words. There is a huge gap bewteen "fake" and "reliable". "Reliable" has shorter content.
#
# The high-frequency words in "fake" and "others" are quite similar, which is hard to distinguish.
# On the other hand,  "Reliable" contains various of words.

# %% [markdown]
# <table><tr><td bgcolor=#f2ffe5>
#
# # Task_4
#
# </td></tr></table>

# %% [markdown]
# ##  Range of  letters
#
# Extract the articles for a specific range of letters, given by the python expression as below:

# %%
"ABCDEFGHIJKLMNOPRSTUVWZABCDEFGHIJKLMNOPRSTUVWZ"[12%23:12%23+10]
# Out:
# 'MNOPRSTUVW'

# %% [markdown]
# As group 12, 'MNOPRSTUVW' is our range of letters.

# %% [markdown]
# ## Scraping and create data set

# %% [markdown]
# Scraping and create our news-dataset from the website Wikinews "Politics and Conflict" section.

# %%
#simulate click
import requests
from bs4 import BeautifulSoup
import codecs
import csv
from selenium import webdriver
from tqdm.notebook import tqdm
from time import sleep

# %%
#RE
import requests
import re
import time

# %% [markdown]
# ### Method 1: Scrapy by simulate click
# **Fetch data from "Pages in category 'Politics and conflicts'"**

# %% [markdown]
# #### Webdriver ATTENTION!
#
# <table><tr><td bgcolor=#ff9980>
#
# A suitable webdriver is needed for your Browser.
#
# Remember to store it under the same path as this file.
#
#
# </td></tr></table>

# %%
# Here we use Mircosoft Edge webdriver

driver = webdriver.Edge('msedgedriver.exe')

url = 'https://en.wikinews.org/wiki/Category:Politics_and_conflicts'

# driver = webdriver.Edge('msedgedriver.exe')
# driver = webdriver.Chrome (executable_path = " ")


driver.get(url)

# %%
#page = 0
titles_all = []

# write head
with codecs.open('newsvc.csv','w', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(['title', 'url', 'date', 'content'])

#while page < 37: # 7559/200, please update pages before running
for page in tqdm(range(37)):
    soup = BeautifulSoup(driver.page_source, "html.parser")
    current_page = soup.find(id = "mw-pages")
    news_row = []
    filtered = current_page.findAll(name='a',attrs={"href":re.compile(r'^(/wiki/[MNOPRSTUVW])')})
    if filtered:
        for i in filtered:
            title = i.get_text()
            title_url = 'https://en.wikinews.org'+i['href']
            news_page = BeautifulSoup(requests.get(title_url).text, 'html.parser').find(class_="mw-parser-output")
            date = [i.get_text() for i in news_page.findAll(name='strong',attrs={"class":re.compile(r'published')})]
            date = ''.join(date)
            content = [i.get_text() for i in news_page.findAll(name='p')[1:]]
            content = ' '.join(content)
            news_row.append([title, title_url, date, content])
        with codecs.open('newsvc.csv','a+', encoding='utf-8') as f:
            writer = csv.writer(f)
            for data in news_row:
                writer.writerow(data)
    driver.find_element_by_xpath("//a[contains(text(),'next page')]").click()
    #page = page + 1
    #time.sleep(0.5)
driver.quit()

import zipfile
f = zipfile.ZipFile('newsvc.zip','w',zipfile.ZIP_DEFLATED)
f.write(r'newsvc.csv')
f.close()
# Out:
# 100%|██████████| 37/37 [19:37<00:00, 31.82s/it]

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
#
# Comment: Total article nummer is 3628.
#
# The scraped information can be find in "newsvc.csv", which contains "title", "url", "date" and "content".
#
# </td></tr></table>

# %% [markdown]
# ### Method 2: with Regular Expression

# %% [markdown]
# Fetch data from 'Subcategories'

# %%
def read_chr_link(mw_category_group,href,title):
    chr_links=mw_category_group.findChildren(name='a')
    for i in range(len(chr_links)): 
        href.append('https://en.wikinews.org'+chr_links[i]['href'])
        title.append(chr_links[i].text)

def pagesearch(page_url,href,title):
    chr_contents=requests.get(page_url).text
    chr_soup= BeautifulSoup(chr_contents, 'html.parser')
    mw_pages=chr_soup.find(id="mw-pages")
    mw_category=mw_pages.findAll(name='div',attrs={"class":re.compile(r'mw-category')})[0]
    category_num=len(mw_category.findChildren(name='div',attrs={"class":re.compile(r'mw-category-group')}))
    mw_category_group=mw_pages.findAll(name='div',attrs={"class":re.compile(r'mw-category-group')})[0]
    if(category_num<=1):
        read_chr_link(mw_category_group,href,title)
        hreflinks=mw_pages.findAll(name='a',attrs={"title":re.compile(r'Category:Politics and conflicts')})
        if hreflinks[1]: next_page_url=re.sub(r'amp;','','https://en.wikinews.org'+hreflinks[1]['href'])
        elif hreflinks[3]: next_page_url=re.sub(r'amp;','','https://en.wikinews.org'+hreflinks[3]['href'])
        #print("category num:",category_num,",move to next page")
        pagesearch(next_page_url,href,title)
    else:
        read_chr_link(mw_category_group,href,title)
        #print("category num:",category_num,",not move to next page")
    return href

time_start=time.time()
r = requests.get('https://en.wikinews.org/wiki/Category:Politics_and_conflicts')
contents = r.text
news_row = []
for i in contents.split('<'):
    chrlink=re.match(r'a class=\"external text\" href=\"(.*)\">(.+)',i)
    if chrlink:
        if chrlink.group(2) in ['M','N','O','P','R','S','T','U','V','W']:
            href_list=[]; title_list=[]
            href_list=pagesearch(re.sub(r'amp;','',chrlink.group(1)),href_list,title_list)
            #print("char:",chrlink.group(2),"\tnum:",len(href_list))
            #print("first article:",href_list[0])
            #print("last article:",href_list[len(href_list)-1])
            for j in tqdm(range(len(href_list))):
                news_page = BeautifulSoup(requests.get(href_list[j]).text, 'html.parser').find(class_="mw-parser-output")
                date = [idate.get_text() for idate in news_page.findAll(name='strong',attrs={"class":re.compile(r'published')})]
                date = ''.join(date)
                #print(j,href_list[j])
                content = [icontent.get_text() for icontent in news_page.findAll(name='p')[1:]]
                content = ' '.join(content)
                #content = ''.join(content.split('\n'))
                content = content.replace('\n', ' ').replace('\r', ' ')
                news_row.append([chrlink.group(2),j+1,href_list[j],title_list[j],date,content])

time_end=time.time()
print('\ntime cost:',time_end-time_start,'s')
print("total article num:",len(news_row))

output = open('newsre.xls','w',encoding='utf-8')
output.write('char\tnum\thref\ttitle\tdate\tcontent\n')
for i in range(len(news_row)):
	for j in range(len(news_row[i])):
		output.write(str(news_row[i][j]))
		output.write('\t')
	output.write('\n')
output.close()

#print(news_row)
# Out:
# ...
# 100%|██████████| 326/326 [01:59<00:00,  2.74it/s]
# time cost: 1247.4018008708954 s
# total article num: 3702

# %% [markdown]
# <table><tr><td bgcolor=#ffffe5>
#
# Comment:
# Total article nummer is 3702.
#
# Base on different hardware and internet connection, running time can be different.
# In this trial it takes 1247s.
#
# The scraped information can be find in "newsre.xls", which contains "char", "num", "href", "title", "date" and "content".
#
# </td></tr></table>

# %% [markdown]
# ## Conclusion
#
# The tools we used for this task are BeautifulSoup, Regular Expression, selenium, tqdm, requests. The details of these tools are documented in the "Library overview" section (2.1).
#
# The scraped datasets can find in "newsvc.csv" and "newsre.xls". The basic statistic you can find in the comments above.
#
# There are plenty of challenges we faced during the work process, such like error occured by typo, lack of related knowledge.
# Due to the data is pretty messy, it takes long time for us to find the correct regular expression to apply.
#
# We consinder WikiNews as a trustworth source, since there are no fake labels in this dataset. However, we doubt on this choice.
#
# WikiNews works through collaborative journalism, also by citizen journalism. The news could be colored by their own political inclination. If you switch WikiNews to other languages, you will find the news source is not always from the main stream.
#
# In a way, it is hard to evaluate the news from WikiNews, is fake or reliable.

# %% [markdown]
# <table><tr><td bgcolor=#f2ffe5>
#
# # Task_5 & 6
#
# </td></tr></table>

# %% [markdown]
# Hand in and to be evaluated.
